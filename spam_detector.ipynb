# %% [markdown]
# # Spam Detector

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Retrieve the Data
#
# The data is located at [https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv](https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv)
#
# Dataset Source: [UCI Machine Learning Library](https://archive.ics.uci.edu/dataset/94/spambase)
#
# Import the data using Pandas. Display the resulting DataFrame to confirm the import was successful.

# %%
# Import the data
data = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv")
data.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...         0.00        0.000
# ...

# %% [markdown]
# ## Predict Model Performance
#
# You will be creating and comparing two models on this data: a Logistic Regression, and a Random Forests Classifier. Before you create, fit, and score the models, make a prediction as to which model you think will perform better. You do not need to be correct!
#
# Write down your prediction in the designated cells in your Jupyter Notebook, and provide justification for your educated guess.

# %% [markdown]
# My Best Guess prediction: Off the cuff I gather the Random Forest will perform better than logistic due to my swag at this juncture.

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %%
X = data.copy()
X.drop("spam", axis=1, inplace=True)
X.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  word_freq_conference  char_freq_;  \
# ...

# %%
# Create the labels set `y` and features DataFrame `X`
y = data["spam"]
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4596    0
# 4597    0
# 4598    0
# 4599    0
# 4600    0
# Name: spam, Length: 4601, dtype: int64

# %%
# Check the balance of the labels variable (`y`) by using the `value_counts` function.
data['spam'].value_counts()
# Out:
# spam
# 0    2788
# 1    1813
# Name: count, dtype: int64

# %%
# Split the data into X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Review the X_train DatFrame
X_train
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 1813             0.0                0.0           0.00           0.0
# 3029             0.0                0.0           0.00           0.0
# 2489             0.0                0.0           0.00           0.0
# 3039             0.0                0.0           0.00           0.0
# 4571             0.0                0.0           0.46           0.0
# ...              ...                ...            ...           ...
# 2163             0.0                0.0           0.00           0.0
# 3476             0.0                0.0           0.44           0.0
# 2744             0.0                0.0           0.00           0.0
# 4136             0.0                0.0           0.00           0.0
# 470              0.0                0.0           0.00           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# ...

# %% [markdown]
# ## Scale the Features

# %% [markdown]
# Use the `StandardScaler` to scale the features data. Remember that only `X_train` and `X_test` DataFrames should be scaled.

# %%
from sklearn.preprocessing import StandardScaler

# Create the StandardScaler instance
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_train_scaled
# Out:
# array([[-0.34017612, -0.16575841, -0.55757067, ..., -0.05270072,
#         -0.223586  , 10.11579197],
#        [-0.34017612, -0.16575841, -0.55757067, ..., -0.1284321 ,
#         -0.24237383, -0.49458154],
#        [-0.34017612, -0.16575841, -0.55757067, ..., -0.1284321 ,
#         -0.24237383, -0.47300112],
#        ...,
#        [-0.34017612, -0.16575841, -0.55757067, ..., -0.08037532,
#         -0.17661644, -0.31294633],
#        [-0.34017612, -0.16575841, -0.55757067, ..., -0.11827153,
#         -0.23297992, -0.43343702],
#        [-0.34017612, -0.16575841, -0.55757067, ..., -0.10811095,
#         -0.223586  , -0.47120275]])

# %%
# Fit the Standard Scaler with the training data
X_test_scaled = scaler.transform(X_test)
X_test_scaled
# Out:
# array([[-0.34017612, -0.16575841, -0.55757067, ..., -0.03689538,
#          0.03474658, -0.34711533],
#        [-0.34017612, -0.16575841, -0.55757067, ..., -0.12409936,
#         -0.223586  , -0.4118566 ],
#        [ 1.76873242, -0.16575841,  0.70856673, ..., -0.08449447,
#         -0.14373775, -0.27877733],
#        ...,
#        [-0.34017612,  0.345508  , -0.55757067, ..., -0.07491363,
#         -0.12964688, -0.21583444],
#        [-0.34017612, -0.16575841,  6.24791788, ..., -0.11317598,
#         -0.22828296, -0.47120275],
#        [-0.34017612, -0.16575841,  0.273332  , ..., -0.06280027,
#         -0.07328341,  0.06291266]])

# %%
# Scale the training data
#X_train_scaled = X_scaler.transform(X_train)
# X_test_scaled = X_scaler.transform(X_test)

# %%
# Check the max and min of the scaled training and testing sets

print("Scaled data min/max (StandardScaler):")
print("Training data min:",X_train_scaled.min())
print("Training data max:",X_train_scaled.max())
print("Testing data min:",X_test_scaled.min())
print("Testing data max:",X_test_scaled.max())
# Out:
# Scaled data min/max (StandardScaler):
# Training data min: -0.9293719922304045
# Training data max: 46.67082434145288
# Testing data min: -0.9293719922304045
# Testing data max: 37.9196128324273

# %% [markdown]
# ## Create and Fit a Logistic Regression Model
#
# Create a Logistic Regression model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Logistic Regression model and print the model score
# Import `LogisticRegression` from sklearn
from sklearn.linear_model import LogisticRegression

# %%
# Create a `LogisticRegression` function and assign it 
# to a variable named `logistic_regression_model`.

logistic_regression_model = LogisticRegression()

# %%
# Fit the model
logistic_regression_model.fit(X_train, y_train)
# Out:
# c:\Users\vaugh\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Score the model
print(f"Training Data Score: {logistic_regression_model.score(X_train, y_train)}")
print(f"Training Data Score: {logistic_regression_model.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.9228985507246377
# Training Data Score: 0.9183318853171155

# %%
# Generate predictions from the model we just fit
predictions = logistic_regression_model.predict(X_train)

# %%
# Make and save testing predictions with the saved logistic regression model using the test data
results_data = pd.DataFrame({"Prediction": predictions, "Actual": y_train})
results_data


# Review the predictions
# Out:
#       Prediction  Actual
# 1813           1       0
# 3029           0       0
# 2489           0       0
# 3039           0       0
# 4571           0       0
# ...          ...     ...
# 2163           0       0
# 3476           0       0
# 2744           0       0
# 4136           0       0
# 470            1       1
#
# [3450 rows x 2 columns]

# %%
# Apply the fitted model to the `test` dataset
testing_predictions = logistic_regression_model.predict(X_test)

# Save both predictions and values to DF

results_data = pd.DataFrame({
    "Tesing Data Predictions": testing_predictions,
    "Testing Data Actual AKA y test": y_test})

# %%
# Display results DF
results_data
# Out:
#       Tesing Data Predictions  Testing Data Actual AKA y test
# 1730                        1                               1
# 2905                        0                               0
# 348                         1                               1
# 4408                        1                               0
# 1945                        0                               0
# ...                       ...                             ...
# 1866                        0                               0
# 367                         1                               1
# 3081                        0                               0
# 2773                        0                               0
# 2952                        0                               0
#
# [1151 rows x 2 columns]

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.
from sklearn.metrics import accuracy_score 

accuracy_score(y_test, testing_predictions)
# Out:
# 0.9183318853171155

# %% [markdown]
# ## Create and Fit a Random Forest Classifier Model
#
# Create a Random Forest Classifier model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Random Forest Classifier model and print the model score
from sklearn.ensemble import RandomForestClassifier

# %%
# Make and save testing predictions with the saved logistic regression model using the test data
RForestClassifier = RandomForestClassifier(n_estimators=96, random_state=1)

# Fit the MDL to trained data
RForestClassifier.fit(X_train_scaled, y_train)

# Review the predictions
print(f"Training Data Score: {RForestClassifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {RForestClassifier.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.9994202898550725
# Testing Data Score: 0.9539530842745438

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.
acc_score = accuracy_score(y_test, testing_predictions)

# %% [markdown]
# ## Evaluate the Models
#
# Which model performed better? How does that compare to your prediction? Write down your results and thoughts in the following markdown cell.

# %% [markdown]
# The Logistic Regression Model was by far most productive to the extent I beleive the execution of the RadomForest model resulting in "0.0" is highly questionable needs to be validated.
